# %% [markdown]
# ### Business Analytics Group Assignment - Predicting Airbnb Listing Prices in Melbourne__ {-}

# %% [markdown]
# ---
#
# **Kaggle Competition Ends:** Friday, 2 June 2023 @ 3:00pm (Week 13)
# **Assignment Due Date on iLearn:** Friday, 2 June 2023 @ 11.59pm (Week 13)
#
# **Overview:**
#
# - In the group assignment you will form a team of 3 students and participate in a forecasting competition on Kaggle
# - The goal is to predict listed prices of Airbnb properties in Melbourne based on various Airbnb characteristics and regression models
# - Assessment Summary:
#     - Write a problem statement and perform Exploratory Data Analysis
#     - Clean up data, deal with categorical features and missing observations, and create new explanatory variables (feature engineering)
#     - Construct and tune forecasting models, produce forecasts and submit your predictions to Kaggle
#     - Each member of the team will record a video presentation of their work
#     - Marks will be awarded producing a prediction in the top 5 positions of their unit as well as for reaching the highest ranking on Kaggle amongst all teams.

# %% [markdown]
# **Instructions:**
#
# - Form a team of 3 students (minimum 2 students)
# - Each team member needs to join [https://www.kaggle.com](https://www.kaggle.com/)
# - Choose a team leader and form a team in the competition [https://www.kaggle.com/t/a154f28787174b628a2b7eaa238a5c12](https://www.kaggle.com/t/a154f28787174b628a2b7eaa238a5c12)
#     - Team leader to click on `team` and join and invite other team members to join
#     - Your **team's name must start** with your unit code, for instance you could have a team called BUSA8001_masterful_geniuses or BUSA3020_l33t
# - All team members should work on all the tasks listed below however
#     - Choose a team member who will be responsible for one of each of the 3 tasks listed below
# - Your predictions must be generated by a model you develop here
#     - You will receive a mark of zero if your code provided here does not produce the forecasts you submit to Kaggle

# %% [markdown]
# **Marks**:
#
# - Total Marks: 40
# - Your individual mark will consist of:
#     - 50% x overall assignment mark + 45% x mark for the task that you are responsible for + 5% x mark received from your teammates for your effort in group work

# %% [markdown]
# **Competition Marks:**
#
# - 1 mark: Ranking in the top 5 places of your unit on Kaggle (make sure you name your team as instructed above)
# - 2 marks: Reaching the first place in your unit (make sure you name your team as instructed above)

# %% [markdown]
# **Submissions:**
#
# 1. On Kaggle: submit your team's forecast in order to be ranked by Kaggle
#     - Can do this as many times as necessary while building their model
# 2. On iLearn **only team leader to submit** this Jupyter notebook re-named `Group_Assignment_Team_Name.ipynb` where Team_Name is your team's name on Kaggle
#     - The Jupyter notebook must contain team members names/ID numbers, and team name in the competition
#     - Provide answers to the 3 Tasks below in the allocated cells including all codes/outputs/writeups
#     - One 15 minute video recording of your work
#         - Each team member to provide a 5 minute presentation of the Task that they led (it is best to jointly record your video using Zoom)
#         - When recording your video make sure your face is visible, that you share your Jupyter Notebook and explain everything you've done in the submitted Jupyter notebook on screen
#         - 5 marks will be deducted from each Task for which there is no video presentation or if you don't follow the above instructions
#
# 3. On iLearn each student needs to submit a file with their teammates' names, ID number and a mark for their group effort (out of 100%)

# %% [markdown]
# ---

# %% [markdown]
# **Fill out the following information**
#
# For each team member provide name, Student ID number and which task is performed below

# %% [markdown]
# - Team Name on Kaggle: `(insert here)`
# - Team Leader and Team Member 1: `(insert here)`
# - Team Member 2: `(insert here)`
# - Team Member 3: `(insert here)`

# %% [markdown]
# ---
#
# ## Task 1: Problem Description and Initial Data Analysis {-}
#
# 1. Read the Competition Overview on Kaggle [https://www.kaggle.com/t/a154f28787174b628a2b7eaa238a5c12](https://www.kaggle.com/t/a154f28787174b628a2b7eaa238a5c12)
# 2. Referring to Competition Overview and the data provided on Kaggle write about a 500 words **Problem Description** focusing on key points that will need to be addressed as first steps in Tasks 2 and 3 below, using the following headings:
#     - Forecasting Problem - explain what you are trying to do and how it could be used in the real world (i.e. why it may be important)
#     - Evaluation Criteria - explain the criteria is used to assess forecast performance
#     - Types of Variables/Features
#     - Data summary and main data characteristics
#     - Missing Values (only explain what you found at this stage)
#     - Hint: you should **not** discuss any specific predictive algorithms at this stage
#     - Note: This task should be completed in a single Markdown cell (text box)
#
# Total Marks: 12

# %%
import pandas as pd 

import matplotlib.pyplot as plt

import numpy as np

pd.set_option("display.max_rows", None, "display.max_columns", None, "display.width", None) # pretty printing

np.set_printoptions(precision=3, suppress = True)       # format printing to 3 decimal places in numpy

# %%
import pandas as pd
df_train = pd.read_csv('Data files/train.csv',skipinitialspace=True)
df_test = pd.read_csv('Data files/test.csv',skipinitialspace=True)
df_sample_submission = pd.read_csv('Data files/sample_submission.csv')
df_metaData = pd.read_csv('Data files/metaData.csv')

# %%
df_train.head()
# Out:
#    ID       source                                           name  \
# 0   0  city scrape                          The Stables, Richmond
# 1   1  city scrape  Room in Cool Deco Apartment in Brunswick East
# 2   2  city scrape                    The Suite @ Angelus Retreat
# 3   3  city scrape            Million Dollar Views Over Melbourne
# 4   4  city scrape             Melbourne - Old Trafford Apartment
#
#                                          description  \
# 0  Superbly located hotel style accommodation in ...
# 1  A large air conditioned room with firm queen s...
# 2  <b>The space</b><br />Welcome to ANGELUS Retre...
# 3  <b>The space</b><br /><b>Enjoy Million Dollar ...
# 4  After hosting many guests from all over the wo...
#
#                                neighborhood_overview      host_name  \
# 0  Richmond is a great neighbourhood.  A beautifu...           Ione
# 1  This hip area is a crossroads between two grea...        Lindsay
# 2                                                NaN  Margaret Jiin
# 3                                                NaN           Paul
# 4  Our street is quiet & secluded but within walk...    Daryl & Dee
#
#    host_since         host_location  \
# 0  2013-03-16  Melbourne, Australia
# 1  2009-09-16  Melbourne, Australia
# 2  2011-11-28  Melbourne, Australia
# 3  2010-06-13  Melbourne, Australia
# 4  2010-07-12    Berwick, Australia
#
#                                           host_about  host_response_time  \
# 0  I'm a working mum who loves being able to shar...      within an hour
# 1  As an artist working in animation and video I ...  within a few hours
# 2  I have very special interests in Life and Life...  within a few hours
# 3  Professional couple who enjoy entertaining in ...        within a day
# 4  We are an active couple who work from home and...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  98%                 f
# 1               100%                  98%                 f
# 2               100%                  78%                 t
# 3                75%                  92%                 f
# 4               100%                  87%                 t
#
#   host_neighbourhood  host_listings_count                host_verifications  \
# 0           Richmond                  2.0                ['email', 'phone']
# 1          Brunswick                  1.0                ['email', 'phone']
# 2                NaN                  2.0                ['email', 'phone']
# 3          Southbank                  4.0                ['email', 'phone']
# 4                NaN                  1.0  ['email', 'phone', 'work_email']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      t
# 2                    t                      t
# 3                    t                      t
# 4                    t                      t
#
#                          neighbourhood neighbourhood_cleansed  latitude  \
# 0        Richmond, Victoria, Australia                  Yarra -37.82030
# 1  Brunswick East, Victoria, Australia               Moreland -37.76606
# 2                                  NaN           Yarra Ranges -37.90546
# 3                                  NaN              Melbourne -37.82163
# 4         Berwick, Victoria, Australia                    NaN -38.05725
#
#    longitude                property_type        room_type  accommodates  \
# 0  144.99016            Entire guesthouse  Entire home/apt             2
# 1  144.97951  Private room in rental unit     Private room             2
# 2  145.39447           Entire rental unit  Entire home/apt             4
# 3  144.96672  Private room in rental unit     Private room             2
# 4  145.33936           Entire rental unit  Entire home/apt             5
#
#        bathrooms  bedrooms  beds  \
# 0         1 bath       1.0   1.0
# 1  1 shared bath       1.0   1.0
# 2      2.5 baths       2.0   4.0
# 3      2.5 baths       1.0   1.0
# 4         1 bath       3.0   3.0
#
#                                            amenities  minimum_nights  \
# 0  ["Sukin conditioner", "Extra pillows and blank...               2
# 1  ["Extra pillows and blankets", "Laundromat nea...               4
# 2  ["Microwave", "Hot tub", "Conditioner", "Smoke...               2
# 3  ["Hot tub", "Gym", "Washer", "Dryer", "Kitchen...               1
# 4  ["Laundromat nearby", "Private patio or balcon...               1
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              14                     2.0                       2
# 1              27                     4.0                       4
# 2             365                     2.0                       2
# 3             730                     1.0                       1
# 4              14                     1.0                       1
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                  1125.0                     2.0
# 1                      27                    27.0                     4.0
# 2                     365                   365.0                     2.0
# 3                     730                   730.0                     1.0
# 4                      14                    14.0                     1.0
#
#    maximum_nights_avg_ntm has_availability  availability_30  availability_60  \
# 0                  1125.0                t                0                0
# 1                    27.0                t                0               12
# 2                   365.0                t               30               60
# 3                   730.0                t               30               60
# 4                    14.0                t               17               21
#
#    availability_90  availability_365  number_of_reviews  \
# 0                0              12.0                741
# 1               22             112.0                169
# 2               90             365.0                  8
# 3               90             365.0                  2
# 4               51             312.0                214
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                     37                       1   2013-03-29  2023-02-18
# 1                     25                       3   2013-01-12  2023-03-08
# 2                      2                       0   2015-07-06  2022-06-13
# 3                      0                       0   2011-10-16  2012-01-27
# 4                     39                       4   2010-11-24  2023-03-03
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.88                    4.91                       4.97
# 1                  4.48                    4.64                       3.97
# 2                  4.75                    4.88                       4.75
# 3                  4.50                    4.00                       4.50
# 4                  4.86                    4.91                       4.98
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.94                         4.93                    4.93
# 1                   4.72                         4.69                    4.65
# 2                   4.88                         4.50                    5.00
# 3                   4.00                         4.00                    5.00
# 4                   4.91                         4.93                    4.90
#
#    review_scores_value instant_bookable  calculated_host_listings_count  \
# 0                 4.82                f                               2
# 1                 4.60                f                               1
# 2                 4.75                f                               2
# 3                 4.00                f                               1
# 4                 4.87                f                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            0
# 2                                            2
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             1
# 2                                             0
# 3                                             1
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month      price
# 0                                            0               6.11    $132.00
# 1                                            0               1.37     $39.00
# 2                                            0               0.09    $270.00
# 3                                            0               0.01  $1,000.00
# 4                                            0               1.43    $116.00

# %%
df = pd.concat([df_test, df_train])
df.shape
# Out:
# (10000, 61)

# %%
df_train.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df_train.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
import matplotlib.pyplot as plt

import seaborn as sns

sns.pairplot(df_train)

plt.show()

# %%
#df.isna().sum()

# %%
df_train.corr()
# Out:
#                                                     ID  host_listings_count  \
# ID                                            1.000000             0.106085
# host_listings_count                           0.106085             1.000000
# latitude                                      0.011285             0.028119
# longitude                                     0.013168            -0.103399
# accommodates                                  0.065331            -0.014715
# bedrooms                                      0.067040            -0.019386
# beds                                          0.034541             0.005564
# minimum_nights                               -0.035845             0.020341
# maximum_nights                               -0.016394             0.026828
# minimum_minimum_nights                       -0.048258             0.016827
# maximum_minimum_nights                       -0.031778             0.025343
# minimum_maximum_nights                        0.009421            -0.003629
# maximum_maximum_nights                        0.030142            -0.010156
# minimum_nights_avg_ntm                       -0.038600             0.026830
# maximum_nights_avg_ntm                        0.030071            -0.010132
# availability_30                               0.143130             0.091885
# availability_60                               0.144180             0.125083
# availability_90                               0.135360             0.115143
# availability_365                             -0.011945            -0.095217
# number_of_reviews                            -0.357456            -0.113059
# number_of_reviews_ltm                         0.070844            -0.085129
# number_of_reviews_l30d                        0.027147            -0.102705
# review_scores_rating                         -0.081644            -0.142832
# review_scores_accuracy                       -0.132915            -0.164266
# review_scores_cleanliness                    -0.125491            -0.217023
# review_scores_checkin                        -0.146275            -0.132994
# review_scores_communication                  -0.140618            -0.165957
# review_scores_location                       -0.065892            -0.050342
# review_scores_value                          -0.138477            -0.181868
# calculated_host_listings_count                0.093259             0.958030
# calculated_host_listings_count_entire_homes   0.136694             0.742594
# calculated_host_listings_count_private_rooms  0.041809             0.853447
# calculated_host_listings_count_shared_rooms   0.030876             0.001248
# reviews_per_month                             0.109454            -0.090200
#
#                                               latitude  longitude  \
# ID                                            0.011285   0.013168
# host_listings_count                           0.028119  -0.103399
# latitude                                      1.000000   0.032286
# longitude                                     0.032286   1.000000
# accommodates                                  0.023989   0.053354
# bedrooms                                      0.027051   0.087288
# beds                                          0.023182   0.060417
# minimum_nights                               -0.005950  -0.040829
# maximum_nights                                0.007316  -0.027583
# minimum_minimum_nights                       -0.010008  -0.050667
# maximum_minimum_nights                       -0.006711  -0.049737
# minimum_maximum_nights                        0.002645  -0.005166
# maximum_maximum_nights                        0.007294  -0.017386
# minimum_nights_avg_ntm                       -0.008851  -0.052605
# maximum_nights_avg_ntm                        0.007242  -0.017310
# availability_30                              -0.027358   0.153125
# availability_60                              -0.028001   0.103391
# availability_90                              -0.018533   0.105414
# availability_365                             -0.004100   0.134028
# number_of_reviews                             0.066783   0.065357
# number_of_reviews_ltm                         0.087145   0.049451
# number_of_reviews_l30d                        0.053466   0.017823
# review_scores_rating                          0.014670   0.085317
# review_scores_accuracy                        0.004600   0.082989
# review_scores_cleanliness                     0.000209   0.119951
# review_scores_checkin                         0.004777   0.102393
# review_scores_communication                  -0.001915   0.067301
# review_scores_location                        0.030951   0.058974
# review_scores_value                          -0.004770   0.039826
# calculated_host_listings_count                0.037220  -0.099714
# calculated_host_listings_count_entire_homes   0.002838  -0.140610
# calculated_host_listings_count_private_rooms  0.049842  -0.047934
# calculated_host_listings_count_shared_rooms   0.003391  -0.032384
# reviews_per_month                             0.084442   0.064051
#
#                                               accommodates  bedrooms  \
# ID                                                0.065331  0.067040
# host_listings_count                              -0.014715 -0.019386
# latitude                                          0.023989  0.027051
# longitude                                         0.053354  0.087288
# accommodates                                      1.000000  0.861955
# bedrooms                                          0.861955  1.000000
# beds                                              0.880401  0.833134
# minimum_nights                                   -0.013334 -0.012242
# maximum_nights                                    0.080489  0.053472
# minimum_minimum_nights                           -0.019945 -0.006820
# maximum_minimum_nights                           -0.001080 -0.002131
# minimum_maximum_nights                            0.000763  0.002492
# maximum_maximum_nights                           -0.019024  0.000347
# minimum_nights_avg_ntm                           -0.009426 -0.007399
# maximum_nights_avg_ntm                           -0.018992  0.000361
# availability_30                                   0.108196  0.101456
# availability_60                                   0.073818  0.069983
# availability_90                                   0.056538  0.059071
# availability_365                                  0.085096  0.082797
# number_of_reviews                                -0.026409 -0.074300
# number_of_reviews_ltm                            -0.000164 -0.038222
# number_of_reviews_l30d                           -0.053431 -0.079910
# review_scores_rating                             -0.001453 -0.005659
# review_scores_accuracy                           -0.006179 -0.010167
# review_scores_cleanliness                        -0.033640 -0.029919
# review_scores_checkin                            -0.004053  0.008095
# review_scores_communication                       0.009784  0.000222
# review_scores_location                            0.040319  0.015477
# review_scores_value                              -0.040498 -0.041573
# calculated_host_listings_count                   -0.031502 -0.033809
# calculated_host_listings_count_entire_homes       0.134314  0.080920
# calculated_host_listings_count_private_rooms     -0.128366 -0.099138
# calculated_host_listings_count_shared_rooms      -0.005331 -0.030520
# reviews_per_month                                -0.003935 -0.047704
#
#                                                   beds  minimum_nights  \
# ID                                            0.034541       -0.035845
# host_listings_count                           0.005564        0.020341
# latitude                                      0.023182       -0.005950
# longitude                                     0.060417       -0.040829
# accommodates                                  0.880401       -0.013334
# bedrooms                                      0.833134       -0.012242
# beds                                          1.000000       -0.013599
# minimum_nights                               -0.013599        1.000000
# maximum_nights                                0.065224        0.010927
# minimum_minimum_nights                       -0.014846        0.627729
# maximum_minimum_nights                       -0.003495        0.928501
# minimum_maximum_nights                       -0.001775       -0.002215
# maximum_maximum_nights                       -0.018141       -0.007365
# minimum_nights_avg_ntm                       -0.008283        0.961037
# maximum_nights_avg_ntm                       -0.018101       -0.007351
# availability_30                               0.099428       -0.039025
# availability_60                               0.065287       -0.042650
# availability_90                               0.054037       -0.039955
# availability_365                              0.086023       -0.016200
# number_of_reviews                            -0.057869       -0.051753
# number_of_reviews_ltm                        -0.046289       -0.090623
# number_of_reviews_l30d                       -0.076437       -0.078352
# review_scores_rating                         -0.008158       -0.031365
# review_scores_accuracy                       -0.016919       -0.022560
# review_scores_cleanliness                    -0.035391       -0.014391
# review_scores_checkin                         0.005924        0.005487
# review_scores_communication                   0.004715       -0.009211
# review_scores_location                        0.020380        0.005994
# review_scores_value                          -0.043635       -0.009511
# calculated_host_listings_count               -0.003551        0.017967
# calculated_host_listings_count_entire_homes   0.129117        0.010697
# calculated_host_listings_count_private_rooms -0.087872        0.018332
# calculated_host_listings_count_shared_rooms   0.010709       -0.013369
# reviews_per_month                            -0.051348       -0.076022
#
#                                               maximum_nights  \
# ID                                                 -0.016394
# host_listings_count                                 0.026828
# latitude                                            0.007316
# longitude                                          -0.027583
# accommodates                                        0.080489
# bedrooms                                            0.053472
# beds                                                0.065224
# minimum_nights                                      0.010927
# maximum_nights                                      1.000000
# minimum_minimum_nights                              0.006085
# maximum_minimum_nights                              0.011292
# minimum_maximum_nights                              0.009810
# maximum_maximum_nights                              0.032560
# minimum_nights_avg_ntm                              0.010936
# maximum_nights_avg_ntm                              0.032523
# availability_30                                     0.032040
# availability_60                                     0.027545
# availability_90                                     0.027982
# availability_365                                    0.141006
# number_of_reviews                                   0.002376
# number_of_reviews_ltm                              -0.026832
# number_of_reviews_l30d                             -0.039353
# review_scores_rating                               -0.047722
# review_scores_accuracy                             -0.065813
# review_scores_cleanliness                          -0.060694
# review_scores_checkin                              -0.056144
# review_scores_communication                        -0.063726
# review_scores_location                             -0.046213
# review_scores_value                                -0.077236
# calculated_host_listings_count                      0.021713
# calculated_host_listings_count_entire_homes         0.082197
# calculated_host_listings_count_private_rooms       -0.023084
# calculated_host_listings_count_shared_rooms        -0.017983
# reviews_per_month                                  -0.039236
#
#                                               minimum_minimum_nights  \
# ID                                                         -0.048258
# host_listings_count                                         0.016827
# latitude                                                   -0.010008
# longitude                                                  -0.050667
# accommodates                                               -0.019945
# bedrooms                                                   -0.006820
# beds                                                       -0.014846
# minimum_nights                                              0.627729
# maximum_nights                                              0.006085
# minimum_minimum_nights                                      1.000000
# maximum_minimum_nights                                      0.587921
# minimum_maximum_nights                                     -0.003010
# maximum_maximum_nights                                     -0.009991
# minimum_nights_avg_ntm                                      0.734484
# maximum_nights_avg_ntm                                     -0.009991
# availability_30                                            -0.035111
# availability_60                                            -0.039314
# availability_90                                            -0.035968
# availability_365                                           -0.006107
# number_of_reviews                                          -0.073027
# number_of_reviews_ltm                                      -0.129241
# number_of_reviews_l30d                                     -0.109323
# review_scores_rating                                       -0.057366
# review_scores_accuracy                                     -0.051572
# review_scores_cleanliness                                  -0.026122
# review_scores_checkin                                      -0.004729
# review_scores_communication                                -0.030012
# review_scores_location                                     -0.007998
# review_scores_value                                        -0.012704
# calculated_host_listings_count                              0.021900
# calculated_host_listings_count_entire_homes                -0.001447
# calculated_host_listings_count_private_rooms                0.031661
# calculated_host_listings_count_shared_rooms                -0.019570
# reviews_per_month                                          -0.106054
#
#                                               maximum_minimum_nights  \
# ID                                                         -0.031778
# host_listings_count                                         0.025343
# latitude                                                   -0.006711
# longitude                                                  -0.049737
# accommodates                                               -0.001080
# bedrooms                                                   -0.002131
# beds                                                       -0.003495
# minimum_nights                                              0.928501
# maximum_nights                                              0.011292
# minimum_minimum_nights                                      0.587921
# maximum_minimum_nights                                      1.000000
# minimum_maximum_nights                                     -0.001525
# maximum_maximum_nights                                     -0.003905
# minimum_nights_avg_ntm                                      0.946070
# maximum_nights_avg_ntm                                     -0.003897
# availability_30                                            -0.028855
# availability_60                                            -0.031207
# availability_90                                            -0.028071
# availability_365                                            0.003306
# number_of_reviews                                          -0.046459
# number_of_reviews_ltm                                      -0.093926
# number_of_reviews_l30d                                     -0.081447
# review_scores_rating                                       -0.030053
# review_scores_accuracy                                     -0.022089
# review_scores_cleanliness                                  -0.014620
# review_scores_checkin                                       0.001501
# review_scores_communication                                -0.010537
# review_scores_location                                      0.011939
# review_scores_value                                        -0.013691
# calculated_host_listings_count                              0.020469
# calculated_host_listings_count_entire_homes                 0.030291
# calculated_host_listings_count_private_rooms                0.009405
# calculated_host_listings_count_shared_rooms                -0.016367
# reviews_per_month                                          -0.074637
#
#                                               minimum_maximum_nights  \
# ID                                                          0.009421
# host_listings_count                                        -0.003629
# latitude                                                    0.002645
# longitude                                                  -0.005166
# accommodates                                                0.000763
# bedrooms                                                    0.002492
# beds                                                       -0.001775
# minimum_nights                                             -0.002215
# maximum_nights                                              0.009810
# minimum_minimum_nights                                     -0.003010
# maximum_minimum_nights                                     -0.001525
# minimum_maximum_nights                                      1.000000
# maximum_maximum_nights                                      0.301295
# minimum_nights_avg_ntm                                     -0.002548
# maximum_nights_avg_ntm                                      0.302167
# availability_30                                             0.023021
# availability_60                                             0.018847
# availability_90                                             0.016555
# availability_365                                            0.007739
# number_of_reviews                                          -0.006304
# number_of_reviews_ltm                                      -0.004829
# number_of_reviews_l30d                                     -0.008193
# review_scores_rating                                       -0.014555
# review_scores_accuracy                                     -0.019627
# review_scores_cleanliness                                  -0.020498
# review_scores_checkin                                      -0.021597
# review_scores_communication                                -0.018307
# review_scores_location                                     -0.022286
# review_scores_value                                        -0.013078
# calculated_host_listings_count                             -0.003223
# calculated_host_listings_count_entire_homes                -0.004127
# calculated_host_listings_count_private_rooms               -0.001804
# calculated_host_listings_count_shared_rooms                -0.001171
# reviews_per_month                                          -0.005609
#
#                                               maximum_maximum_nights  \
# ID                                                          0.030142
# host_listings_count                                        -0.010156
# latitude                                                    0.007294
# longitude                                                  -0.017386
# accommodates                                               -0.019024
# bedrooms                                                    0.000347
# beds                                                       -0.018141
# minimum_nights                                             -0.007365
# maximum_nights                                              0.032560
# minimum_minimum_nights                                     -0.009991
# maximum_minimum_nights                                     -0.003905
# minimum_maximum_nights                                      0.301295
# maximum_maximum_nights                                      1.000000
# minimum_nights_avg_ntm                                     -0.008946
# maximum_nights_avg_ntm                                      0.999998
# availability_30                                             0.068869
# availability_60                                             0.058700
# availability_90                                             0.052480
# availability_365                                            0.035544
# number_of_reviews                                          -0.024299
# number_of_reviews_ltm                                      -0.019857
# number_of_reviews_l30d                                     -0.025335
# review_scores_rating                                       -0.008564
# review_scores_accuracy                                     -0.007232
# review_scores_cleanliness                                  -0.016492
# review_scores_checkin                                      -0.012000
# review_scores_communication                                -0.010586
# review_scores_location                                     -0.005716
# review_scores_value                                        -0.022590
# calculated_host_listings_count                             -0.008682
# calculated_host_listings_count_entire_homes                -0.017748
# calculated_host_listings_count_private_rooms               -0.000622
# calculated_host_listings_count_shared_rooms                -0.003910
# reviews_per_month                                          -0.019927
#
#                                               minimum_nights_avg_ntm  \
# ID                                                         -0.038600
# host_listings_count                                         0.026830
# latitude                                                   -0.008851
# longitude                                                  -0.052605
# accommodates                                               -0.009426
# bedrooms                                                   -0.007399
# beds                                                       -0.008283
# minimum_nights                                              0.961037
# maximum_nights                                              0.010936
# minimum_minimum_nights                                      0.734484
# maximum_minimum_nights                                      0.946070
# minimum_maximum_nights                                     -0.002548
# maximum_maximum_nights                                     -0.008946
# minimum_nights_avg_ntm                                      1.000000
# maximum_nights_avg_ntm                                     -0.008938
# availability_30                                            -0.035897
# availability_60                                            -0.038680
# availability_90                                            -0.035456
# availability_365                                           -0.002430
# number_of_reviews                                          -0.061182
# number_of_reviews_ltm                                      -0.113055
# number_of_reviews_l30d                                     -0.095725
# review_scores_rating                                       -0.040208
# review_scores_accuracy                                     -0.032110
# review_scores_cleanliness                                  -0.021491
# review_scores_checkin                                       0.002204
# review_scores_communication                                -0.014986
# review_scores_location                                      0.006156
# review_scores_value                                        -0.014219
# calculated_host_listings_count                              0.024182
# calculated_host_listings_count_entire_homes                 0.024055
# calculated_host_listings_count_private_rooms                0.018558
# calculated_host_listings_count_shared_rooms                -0.017751
# reviews_per_month                                          -0.092683
#
#                                               maximum_nights_avg_ntm  \
# ID                                                          0.030071
# host_listings_count                                        -0.010132
# latitude                                                    0.007242
# longitude                                                  -0.017310
# accommodates                                               -0.018992
# bedrooms                                                    0.000361
# beds                                                       -0.018101
# minimum_nights                                             -0.007351
# maximum_nights                                              0.032523
# minimum_minimum_nights                                     -0.009991
# maximum_minimum_nights                                     -0.003897
# minimum_maximum_nights                                      0.302167
# maximum_maximum_nights                                      0.999998
# minimum_nights_avg_ntm                                     -0.008938
# maximum_nights_avg_ntm                                      1.000000
# availability_30                                             0.068623
# availability_60                                             0.058499
# availability_90                                             0.052295
# availability_365                                            0.035496
# number_of_reviews                                          -0.024195
# number_of_reviews_ltm                                      -0.019789
# number_of_reviews_l30d                                     -0.025268
# review_scores_rating                                       -0.008547
# review_scores_accuracy                                     -0.007143
# review_scores_cleanliness                                  -0.016366
# review_scores_checkin                                      -0.011948
# review_scores_communication                                -0.010544
# review_scores_location                                     -0.005697
# review_scores_value                                        -0.022517
# calculated_host_listings_count                             -0.008666
# calculated_host_listings_count_entire_homes                -0.017708
# calculated_host_listings_count_private_rooms               -0.000631
# calculated_host_listings_count_shared_rooms                -0.003885
# reviews_per_month                                          -0.019860
#
#                                               availability_30  \
# ID                                                   0.143130
# host_listings_count                                  0.091885
# latitude                                            -0.027358
# longitude                                            0.153125
# accommodates                                         0.108196
# bedrooms                                             0.101456
# beds                                                 0.099428
# minimum_nights                                      -0.039025
# maximum_nights                                       0.032040
# minimum_minimum_nights                              -0.035111
# maximum_minimum_nights                              -0.028855
# minimum_maximum_nights                               0.023021
# maximum_maximum_nights                               0.068869
# minimum_nights_avg_ntm                              -0.035897
# maximum_nights_avg_ntm                               0.068623
# availability_30                                      1.000000
# availability_60                                      0.887839
# availability_90                                      0.792570
# availability_365                                     0.391918
# number_of_reviews                                   -0.102996
# number_of_reviews_ltm                               -0.011574
# number_of_reviews_l30d                              -0.022313
# review_scores_rating                                -0.112095
# review_scores_accuracy                              -0.135901
# review_scores_cleanliness                           -0.098992
# review_scores_checkin                               -0.118977
# review_scores_communication                         -0.142152
# review_scores_location                              -0.093537
# review_scores_value                                 -0.188091
# calculated_host_listings_count                       0.096810
# calculated_host_listings_count_entire_homes          0.082912
# calculated_host_listings_count_private_rooms         0.080518
# calculated_host_listings_count_shared_rooms          0.023553
# reviews_per_month                                   -0.019869
#
#                                               availability_60  \
# ID                                                   0.144180
# host_listings_count                                  0.125083
# latitude                                            -0.028001
# longitude                                            0.103391
# accommodates                                         0.073818
# bedrooms                                             0.069983
# beds                                                 0.065287
# minimum_nights                                      -0.042650
# maximum_nights                                       0.027545
# minimum_minimum_nights                              -0.039314
# maximum_minimum_nights                              -0.031207
# minimum_maximum_nights                               0.018847
# maximum_maximum_nights                               0.058700
# minimum_nights_avg_ntm                              -0.038680
# maximum_nights_avg_ntm                               0.058499
# availability_30                                      0.887839
# availability_60                                      1.000000
# availability_90                                      0.954910
# availability_365                                     0.475205
# number_of_reviews                                   -0.092926
# number_of_reviews_ltm                                0.012479
# number_of_reviews_l30d                               0.000010
# review_scores_rating                                -0.108103
# review_scores_accuracy                              -0.140101
# review_scores_cleanliness                           -0.103565
# review_scores_checkin                               -0.121257
# review_scores_communication                         -0.146210
# review_scores_location                              -0.099640
# review_scores_value                                 -0.187218
# calculated_host_listings_count                       0.133872
# calculated_host_listings_count_entire_homes          0.109599
# calculated_host_listings_count_private_rooms         0.115111
# calculated_host_listings_count_shared_rooms          0.008640
# reviews_per_month                                   -0.008310
#
#                                               availability_90  \
# ID                                                   0.135360
# host_listings_count                                  0.115143
# latitude                                            -0.018533
# longitude                                            0.105414
# accommodates                                         0.056538
# bedrooms                                             0.059071
# beds                                                 0.054037
# minimum_nights                                      -0.039955
# maximum_nights                                       0.027982
# minimum_minimum_nights                              -0.035968
# maximum_minimum_nights                              -0.028071
# minimum_maximum_nights                               0.016555
# maximum_maximum_nights                               0.052480
# minimum_nights_avg_ntm                              -0.035456
# maximum_nights_avg_ntm                               0.052295
# availability_30                                      0.792570
# availability_60                                      0.954910
# availability_90                                      1.000000
# availability_365                                     0.540816
# number_of_reviews                                   -0.079921
# number_of_reviews_ltm                                0.023803
# number_of_reviews_l30d                               0.012926
# review_scores_rating                                -0.095446
# review_scores_accuracy                              -0.130248
# review_scores_cleanliness                           -0.091309
# review_scores_checkin                               -0.104197
# review_scores_communication                         -0.135580
# review_scores_location                              -0.096408
# review_scores_value                                 -0.174387
# calculated_host_listings_count                       0.124559
# calculated_host_listings_count_entire_homes          0.080350
# calculated_host_listings_count_private_rooms         0.120991
# calculated_host_listings_count_shared_rooms         -0.002914
# reviews_per_month                                    0.000462
#
#                                               availability_365  \
# ID                                                   -0.011945
# host_listings_count                                  -0.095217
# latitude                                             -0.004100
# longitude                                             0.134028
# accommodates                                          0.085096
# bedrooms                                              0.082797
# beds                                                  0.086023
# minimum_nights                                       -0.016200
# maximum_nights                                        0.141006
# minimum_minimum_nights                               -0.006107
# maximum_minimum_nights                                0.003306
# minimum_maximum_nights                                0.007739
# maximum_maximum_nights                                0.035544
# minimum_nights_avg_ntm                               -0.002430
# maximum_nights_avg_ntm                                0.035496
# availability_30                                       0.391918
# availability_60                                       0.475205
# availability_90                                       0.540816
# availability_365                                      1.000000
# number_of_reviews                                    -0.020755
# number_of_reviews_ltm                                -0.016652
# number_of_reviews_l30d                               -0.024440
# review_scores_rating                                 -0.060433
# review_scores_accuracy                               -0.094682
# review_scores_cleanliness                            -0.037111
# review_scores_checkin                                -0.060520
# review_scores_communication                          -0.096761
# review_scores_location                               -0.077068
# review_scores_value                                  -0.128246
# calculated_host_listings_count                       -0.098413
# calculated_host_listings_count_entire_homes          -0.056572
# calculated_host_listings_count_private_rooms         -0.100482
# calculated_host_listings_count_shared_rooms          -0.002216
# reviews_per_month                                    -0.042076
#
#                                               number_of_reviews  \
# ID                                                    -0.357456
# host_listings_count                                   -0.113059
# latitude                                               0.066783
# longitude                                              0.065357
# accommodates                                          -0.026409
# bedrooms                                              -0.074300
# beds                                                  -0.057869
# minimum_nights                                        -0.051753
# maximum_nights                                         0.002376
# minimum_minimum_nights                                -0.073027
# maximum_minimum_nights                                -0.046459
# minimum_maximum_nights                                -0.006304
# maximum_maximum_nights                                -0.024299
# minimum_nights_avg_ntm                                -0.061182
# maximum_nights_avg_ntm                                -0.024195
# availability_30                                       -0.102996
# availability_60                                       -0.092926
# availability_90                                       -0.079921
# availability_365                                      -0.020755
# number_of_reviews                                      1.000000
# number_of_reviews_ltm                                  0.658870
# number_of_reviews_l30d                                 0.471154
# review_scores_rating                                   0.143529
# review_scores_accuracy                                 0.161587
# review_scores_cleanliness                              0.159463
# review_scores_checkin                                  0.122004
# review_scores_communication                            0.144875
# review_scores_location                                 0.130954
# review_scores_value                                    0.170659
# calculated_host_listings_count                        -0.109724
# calculated_host_listings_count_entire_homes           -0.080328
# calculated_host_listings_count_private_rooms          -0.099357
# calculated_host_listings_count_shared_rooms           -0.041602
# reviews_per_month                                      0.703259
#
#                                               number_of_reviews_ltm  \
# ID                                                         0.070844
# host_listings_count                                       -0.085129
# latitude                                                   0.087145
# longitude                                                  0.049451
# accommodates                                              -0.000164
# bedrooms                                                  -0.038222
# beds                                                      -0.046289
# minimum_nights                                            -0.090623
# maximum_nights                                            -0.026832
# minimum_minimum_nights                                    -0.129241
# maximum_minimum_nights                                    -0.093926
# minimum_maximum_nights                                    -0.004829
# maximum_maximum_nights                                    -0.019857
# minimum_nights_avg_ntm                                    -0.113055
# maximum_nights_avg_ntm                                    -0.019789
# availability_30                                           -0.011574
# availability_60                                            0.012479
# availability_90                                            0.023803
# availability_365                                          -0.016652
# number_of_reviews                                          0.658870
# number_of_reviews_ltm                                      1.000000
# number_of_reviews_l30d                                     0.741733
# review_scores_rating                                       0.121325
# review_scores_accuracy                                     0.120060
# review_scores_cleanliness                                  0.108981
# review_scores_checkin                                      0.069099
# review_scores_communication                                0.109038
# review_scores_location                                     0.115602
# review_scores_value                                        0.133246
# calculated_host_listings_count                            -0.081111
# calculated_host_listings_count_entire_homes               -0.038796
# calculated_host_listings_count_private_rooms              -0.086120
# calculated_host_listings_count_shared_rooms               -0.038507
# reviews_per_month                                          0.879329
#
#                                               number_of_reviews_l30d  \
# ID                                                          0.027147
# host_listings_count                                        -0.102705
# latitude                                                    0.053466
# longitude                                                   0.017823
# accommodates                                               -0.053431
# bedrooms                                                   -0.079910
# beds                                                       -0.076437
# minimum_nights                                             -0.078352
# maximum_nights                                             -0.039353
# minimum_minimum_nights                                     -0.109323
# maximum_minimum_nights                                     -0.081447
# minimum_maximum_nights                                     -0.008193
# maximum_maximum_nights                                     -0.025335
# minimum_nights_avg_ntm                                     -0.095725
# maximum_nights_avg_ntm                                     -0.025268
# availability_30                                            -0.022313
# availability_60                                             0.000010
# availability_90                                             0.012926
# availability_365                                           -0.024440
# number_of_reviews                                           0.471154
# number_of_reviews_ltm                                       0.741733
# number_of_reviews_l30d                                      1.000000
# review_scores_rating                                        0.141000
# review_scores_accuracy                                      0.142666
# review_scores_cleanliness                                   0.135902
# review_scores_checkin                                       0.103280
# review_scores_communication                                 0.131269
# review_scores_location                                      0.105646
# review_scores_value                                         0.158732
# calculated_host_listings_count                             -0.096770
# calculated_host_listings_count_entire_homes                -0.092465
# calculated_host_listings_count_private_rooms               -0.073734
# calculated_host_listings_count_shared_rooms                -0.040991
# reviews_per_month                                           0.667375
#
#                                               review_scores_rating  \
# ID                                                       -0.081644
# host_listings_count                                      -0.142832
# latitude                                                  0.014670
# longitude                                                 0.085317
# accommodates                                             -0.001453
# bedrooms                                                 -0.005659
# beds                                                     -0.008158
# minimum_nights                                           -0.031365
# maximum_nights                                           -0.047722
# minimum_minimum_nights                                   -0.057366
# maximum_minimum_nights                                   -0.030053
# minimum_maximum_nights                                   -0.014555
# maximum_maximum_nights                                   -0.008564
# minimum_nights_avg_ntm                                   -0.040208
# maximum_nights_avg_ntm                                   -0.008547
# availability_30                                          -0.112095
# availability_60                                          -0.108103
# availability_90                                          -0.095446
# availability_365                                         -0.060433
# number_of_reviews                                         0.143529
# number_of_reviews_ltm                                     0.121325
# number_of_reviews_l30d                                    0.141000
# review_scores_rating                                      1.000000
# review_scores_accuracy                                    0.894164
# review_scores_cleanliness                                 0.841143
# review_scores_checkin                                     0.801143
# review_scores_communication                               0.825967
# review_scores_location                                    0.635738
# review_scores_value                                       0.852427
# calculated_host_listings_count                           -0.123989
# calculated_host_listings_count_entire_homes              -0.149775
# calculated_host_listings_count_private_rooms             -0.074753
# calculated_host_listings_count_shared_rooms              -0.047951
# reviews_per_month                                         0.118558
#
#                                               review_scores_accuracy  \
# ID                                                         -0.132915
# host_listings_count                                        -0.164266
# latitude                                                    0.004600
# longitude                                                   0.082989
# accommodates                                               -0.006179
# bedrooms                                                   -0.010167
# beds                                                       -0.016919
# minimum_nights                                             -0.022560
# maximum_nights                                             -0.065813
# minimum_minimum_nights                                     -0.051572
# maximum_minimum_nights                                     -0.022089
# minimum_maximum_nights                                     -0.019627
# maximum_maximum_nights                                     -0.007232
# minimum_nights_avg_ntm                                     -0.032110
# maximum_nights_avg_ntm                                     -0.007143
# availability_30                                            -0.135901
# availability_60                                            -0.140101
# availability_90                                            -0.130248
# ...
# number_of_reviews                                        0.170659
# number_of_reviews_ltm                                    0.133246
# number_of_reviews_l30d                                   0.158732
# review_scores_rating                                     0.852427
# review_scores_accuracy                                   0.828714
# review_scores_cleanliness                                0.748948
# review_scores_checkin                                    0.725298
# review_scores_communication                              0.754939
# review_scores_location                                   0.626994
# review_scores_value                                      1.000000
# calculated_host_listings_count                          -0.170935
# calculated_host_listings_count_entire_homes             -0.202726
# calculated_host_listings_count_private_rooms            -0.105957
# calculated_host_listings_count_shared_rooms             -0.036015
# reviews_per_month                                        0.130996
#
#                                               calculated_host_listings_count  \
# ID                                                                  0.093259
# host_listings_count                                                 0.958030
# latitude                                                            0.037220
# longitude                                                          -0.099714
# accommodates                                                       -0.031502
# bedrooms                                                           -0.033809
# beds                                                               -0.003551
# minimum_nights                                                      0.017967
# maximum_nights                                                      0.021713
# minimum_minimum_nights                                              0.021900
# maximum_minimum_nights                                              0.020469
# minimum_maximum_nights                                             -0.003223
# maximum_maximum_nights                                             -0.008682
# minimum_nights_avg_ntm                                              0.024182
# maximum_nights_avg_ntm                                             -0.008666
# availability_30                                                     0.096810
# availability_60                                                     0.133872
# availability_90                                                     0.124559
# availability_365                                                   -0.098413
# number_of_reviews                                                  -0.109724
# number_of_reviews_ltm                                              -0.081111
# number_of_reviews_l30d                                             -0.096770
# review_scores_rating                                               -0.123989
# review_scores_accuracy                                             -0.157679
# review_scores_cleanliness                                          -0.209169
# review_scores_checkin                                              -0.118467
# review_scores_communication                                        -0.155852
# review_scores_location                                             -0.056383
# review_scores_value                                                -0.170935
# calculated_host_listings_count                                      1.000000
# calculated_host_listings_count_entire_homes                         0.749248
# calculated_host_listings_count_private_rooms                        0.907203
# calculated_host_listings_count_shared_rooms                         0.003006
# reviews_per_month                                                  -0.091318
#
#                                               calculated_host_listings_count_entire_homes  \
# ID                                                                               0.136694
# host_listings_count                                                              0.742594
# latitude                                                                         0.002838
# longitude                                                                       -0.140610
# accommodates                                                                     0.134314
# bedrooms                                                                         0.080920
# beds                                                                             0.129117
# minimum_nights                                                                   0.010697
# maximum_nights                                                                   0.082197
# minimum_minimum_nights                                                          -0.001447
# maximum_minimum_nights                                                           0.030291
# minimum_maximum_nights                                                          -0.004127
# maximum_maximum_nights                                                          -0.017748
# minimum_nights_avg_ntm                                                           0.024055
# maximum_nights_avg_ntm                                                          -0.017708
# availability_30                                                                  0.082912
# availability_60                                                                  0.109599
# availability_90                                                                  0.080350
# availability_365                                                                -0.056572
# number_of_reviews                                                               -0.080328
# number_of_reviews_ltm                                                           -0.038796
# number_of_reviews_l30d                                                          -0.092465
# review_scores_rating                                                            -0.149775
# review_scores_accuracy                                                          -0.171672
# review_scores_cleanliness                                                       -0.208611
# review_scores_checkin                                                           -0.189886
# review_scores_communication                                                     -0.182762
# review_scores_location                                                          -0.031629
# review_scores_value                                                             -0.202726
# calculated_host_listings_count                                                   0.749248
# calculated_host_listings_count_entire_homes                                      1.000000
# calculated_host_listings_count_private_rooms                                     0.401386
# calculated_host_listings_count_shared_rooms                                     -0.012247
# reviews_per_month                                                               -0.047705
#
#                                               calculated_host_listings_count_private_rooms  \
# ID                                                                                0.041809
# host_listings_count                                                               0.853447
# latitude                                                                          0.049842
# longitude                                                                        -0.047934
# accommodates                                                                     -0.128366
# bedrooms                                                                         -0.099138
# beds                                                                             -0.087872
# minimum_nights                                                                    0.018332
# maximum_nights                                                                   -0.023084
# minimum_minimum_nights                                                            0.031661
# maximum_minimum_nights                                                            0.009405
# minimum_maximum_nights                                                           -0.001804
# maximum_maximum_nights                                                           -0.000622
# minimum_nights_avg_ntm                                                            0.018558
# maximum_nights_avg_ntm                                                           -0.000631
# availability_30                                                                   0.080518
# availability_60                                                                   0.115111
# availability_90                                                                   0.120991
# availability_365                                                                 -0.100482
# number_of_reviews                                                                -0.099357
# number_of_reviews_ltm                                                            -0.086120
# number_of_reviews_l30d                                                           -0.073734
# review_scores_rating                                                             -0.074753
# review_scores_accuracy                                                           -0.107098
# review_scores_cleanliness                                                        -0.155377
# review_scores_checkin                                                            -0.041591
# review_scores_communication                                                      -0.097497
# review_scores_location                                                           -0.057045
# review_scores_value                                                              -0.105957
# calculated_host_listings_count                                                    0.907203
# calculated_host_listings_count_entire_homes                                       0.401386
# calculated_host_listings_count_private_rooms                                      1.000000
# calculated_host_listings_count_shared_rooms                                       0.001169
# reviews_per_month                                                                -0.094566
#
#                                               calculated_host_listings_count_shared_rooms  \
# ID                                                                               0.030876
# host_listings_count                                                              0.001248
# latitude                                                                         0.003391
# longitude                                                                       -0.032384
# accommodates                                                                    -0.005331
# bedrooms                                                                        -0.030520
# beds                                                                             0.010709
# minimum_nights                                                                  -0.013369
# maximum_nights                                                                  -0.017983
# minimum_minimum_nights                                                          -0.019570
# maximum_minimum_nights                                                          -0.016367
# minimum_maximum_nights                                                          -0.001171
# maximum_maximum_nights                                                          -0.003910
# minimum_nights_avg_ntm                                                          -0.017751
# maximum_nights_avg_ntm                                                          -0.003885
# availability_30                                                                  0.023553
# availability_60                                                                  0.008640
# availability_90                                                                 -0.002914
# availability_365                                                                -0.002216
# number_of_reviews                                                               -0.041602
# number_of_reviews_ltm                                                           -0.038507
# number_of_reviews_l30d                                                          -0.040991
# review_scores_rating                                                            -0.047951
# review_scores_accuracy                                                          -0.046412
# review_scores_cleanliness                                                       -0.067972
# review_scores_checkin                                                           -0.031816
# review_scores_communication                                                     -0.026056
# review_scores_location                                                          -0.034743
# review_scores_value                                                             -0.036015
# calculated_host_listings_count                                                   0.003006
# calculated_host_listings_count_entire_homes                                     -0.012247
# calculated_host_listings_count_private_rooms                                     0.001169
# calculated_host_listings_count_shared_rooms                                      1.000000
# reviews_per_month                                                               -0.040026
#
#                                               reviews_per_month
# ID                                                     0.109454
# host_listings_count                                   -0.090200
# latitude                                               0.084442
# longitude                                              0.064051
# accommodates                                          -0.003935
# bedrooms                                              -0.047704
# beds                                                  -0.051348
# minimum_nights                                        -0.076022
# maximum_nights                                        -0.039236
# minimum_minimum_nights                                -0.106054
# maximum_minimum_nights                                -0.074637
# minimum_maximum_nights                                -0.005609
# maximum_maximum_nights                                -0.019927
# minimum_nights_avg_ntm                                -0.092683
# maximum_nights_avg_ntm                                -0.019860
# availability_30                                       -0.019869
# availability_60                                       -0.008310
# availability_90                                        0.000462
# availability_365                                      -0.042076
# number_of_reviews                                      0.703259
# number_of_reviews_ltm                                  0.879329
# number_of_reviews_l30d                                 0.667375
# review_scores_rating                                   0.118558
# review_scores_accuracy                                 0.119047
# review_scores_cleanliness                              0.108930
# review_scores_checkin                                  0.067022
# review_scores_communication                            0.104426
# review_scores_location                                 0.107266
# review_scores_value                                    0.130996
# calculated_host_listings_count                        -0.091318
# calculated_host_listings_count_entire_homes           -0.047705
# calculated_host_listings_count_private_rooms          -0.094566
# calculated_host_listings_count_shared_rooms           -0.040026
# reviews_per_month                                      1.000000

# %%
import seaborn as sns

corrmat = df_train.corr()
# print(corrmat.round(3).to_string())
#corrmat

f, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(corrmat, annot=True, vmax=.8, square=True)
plt.show()

# %% [markdown]
# histogram matrix

# %% [markdown]
# `(Task 1, Text Here)`

# %% [markdown]
# ---
#
# ## Task 2: Data Cleaning, Missing Observations and Feature Engineering {-}
# - In this task you will follow a set of instructions/questions listed below.
# - Make sure you **explain** each step you do both in Markdown text and on your video.
#     - Do not just read out your commands without explaining what they do and why you used them
#
# Total Marks: 12

# %% [markdown]
# **Task 2, Question 1**: Clean **all** numerical features and the target variable `price` so that they can be used in training algorithms. For instance, `host_response_rate` feature is in object format containing both numerical values and text. Extract numerical values (or equivalently eliminate the text) so that the numerical values can be used as a regular feature.
# (2 marks)

# %%
## Task 2, Question 1 Code Here

# %% [markdown]
# `(Task 2, Question 1 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 2** Create at least 4 new features from existing features which contain multiple items of information, e.g. creating `email`,  `phone`, `work_email`, etc. from feature `host_verifications`.
# (2 marks)

# %%
## Task 2, Question 2 Code Here

# %% [markdown]
# `(Task 2, Question 2 Text Here)`

# %% [markdown]
# **Task 2, Question 3**: Impute missing values for all features in both training and test datasets. Hint: make sure you do **not** impute the price in the test dataset.
# (3 marks)

# %%
## Task 2, Question 3 Code Here

# %% [markdown]
# `(Task 2, Question 3 Text Here)`

# %% [markdown]
# **Task 2, Question 4**: Encode all categorical variables appropriately as discussed in class.
#
#
# Where a categorical feature contains more than 5 unique values, map the feature into 5 most frequent values + 'other' and then encode appropriately. For instance, you could group then map `property_type` into 5 most frequent property types + 'other'
# (2 marks)

# %%
import numpy as np
other_property = df['property_type'].value_counts().index[:5]
df['property_type'] = np.where(df['property_type'].isin(other_property), df['property_type'], 'other')

other_nbd = df['neighbourhood_cleansed'].value_counts().index[:5]
df['neighbourhood_cleansed'] = np.where(df['neighbourhood_cleansed'].isin(other_nbd), df['neighbourhood_cleansed'], 'other')

other_bathroom = df['bathrooms'].value_counts().index[:5]
df['bathrooms'] = np.where(df['bathrooms'].isin(other_bathroom), df['bathrooms'], 'other')

#valCount = df['neighbourhood_cleansed'].value_counts()
#print (valCount)

# %%
mapping = {'t':0,  'f':1}
df['host_is_superhost'] = df['host_is_superhost'].map(mapping)
df['host_identity_verified'] = df['host_identity_verified'].map(mapping)
df['host_has_profile_pic'] = df['host_has_profile_pic'].map(mapping)
df['instant_bookable'] = df['instant_bookable'].map(mapping)
df['has_availability'] = df['has_availability'].map(mapping)

# %% [markdown]
# `(Task 2, Question 4 Text Here)`

# %% [markdown]
# **Task 2, Question 5**: Perform any other actions you think need to be done on the data before constructing predictive models, and clearly explain what you have done.
# (1 marks)

# %%
## Task 2, Question 5 Code Here

# %% [markdown]
# `(Task 2, Question 5 Text Here)`

# %% [markdown]
# **Task 2, Question 6**: Perform exploratory data analysis to measure the relationship between the features and the target and write up your findings.
# (2 marks)

# %%
import seaborn as sns
sns.heatmap(data=df, annot = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 sns.heatmap(data=df, annot = True)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     362 """Plot rectangular data as a color-encoded matrix.
#     363
#     364 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     537     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     538 """
#     539 # Initialize the plotter object
# --> 540 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                       annot_kws, cbar, cbar_kws, xticklabels,
#     542                       yticklabels, mask)
#     544 # Add the pcolormesh kwargs here
#     545 kwargs["linewidths"] = linewidths
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:159, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     156 self.ylabel = ylabel if ylabel is not None else ""
#     158 # Determine good default values for the colormapping
# --> 159 self._determine_cmap_params(plot_data, vmin, vmax,
#     160                             cmap, center, robust)
#     162 # Sort out the annotations
#     163 if annot is None or annot is False:
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:193, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     190 """Use some heuristics to set good defaults for colorbar and range."""
#     192 # plot_data is a np.ma.array instance
# --> 193 calc_data = plot_data.astype(float).filled(np.nan)
#     194 if vmin is None:
#     195     if robust:
#
# ValueError: could not convert string to float: 'city scrape'

# %%
import matplotlib.pyplot as ply 

import seaborn as sns

sns.pairplot(df_train)

plt.show

# %% [markdown]
# `(Task 2, Question 6 Text Here)`

# %% [markdown]
# ---
# ## Task 3: Fit and tune a forecasting model/Submit predictions/Report score and ranking {-}
#
# Make sure you **clearly explain each step** you do, both in text and on the recoded video.
#
# 1. Build a machine learning (ML) regression model by taking into account the outcomes of Tasks 1 & 2 (Explain carefully)
# 2. Fit the model and tune hyperparameters via cross-validation: make sure you comment and explain each step clearly
# 3. Create predictions using the test dataset and submit your predictions on Kaggle's competition page
# 4. Provide Kaggle ranking and **score** (screenshot your best submission) and Comment
# 5. Make sure your Python code works, so that a marker that can replicate your all of your results and obtain the same RMSE from Kaggle
#
# - Hint: to perform well in this assignment you will need to iterate Tasks 2 & 3, creating new features and training various models in order to find the best one.
#
# Total Marks: 12

# %%
#Task 3 code here

# %%
# HAVE TO USE RMSE

# %% [markdown]
# `(Task 3 - insert more cells as required)`
